# %% [markdown]
# ### BIBLIOTECAS NECESSÁRIAS

# %%
import pandas as pd

# %% [markdown]
# #### TRATAMENTO DE DADOS

# %%
df = pd.read_csv("instacart_consolidado.csv")
df_1000 = df.head(1000)
df_1000.to_csv("instacart_1000.csv", index=False)
print(f"Arquivo Tratado!")
# Out:
# Sucesso! Arquivo 'instacart_1000.csv' criado com 1000 linhas.

# %% [markdown]
# ### VIEW FINAL

# %%
df_arquivo_final = pd.read_csv("instacart_1000.csv")
display(df_arquivo_final.head(3))
# Out:
#    order_id                                   product_name  department  \
# 0         1                               Bulgarian Yogurt  dairy eggs
# 1         1  Organic 4% Milk Fat Whole Milk Cottage Cheese  dairy eggs
# 2         1                          Organic Celery Hearts     produce
#
#                   aisle  order_dow  order_hour_of_day  days_since_prior_order  \
# 0                yogurt          4                 10                     9.0
# 1  other creams cheeses          4                 10                     9.0
# 2      fresh vegetables          4                 10                     9.0
#
#    reordered
# 0          1
# 1          1
# 2          0
